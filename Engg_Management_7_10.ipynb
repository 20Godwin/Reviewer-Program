# %% [markdown]
# <a href="https://colab.research.google.com/github/20Godwin/Reviewer-Program/blob/main/Engg_Management_7_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

class Question:
    def __init__(self, question, choices, answer):
        self.question = question
        self.choices = choices
        self.answer = answer

    def ask(self):
        print(self.question)
        for i, choice in enumerate(self.choices, start=1):
            print(f"{i}. {choice}")
        user_answer = input("Enter your answer: ").upper()
        if user_answer == self.answer:
            print("Correct!\n")
        else:
            print("Incorrect. The correct answer is", self.answer + "\n")

class MultipleChoiceReviewer:
    def __init__(self):
        self.questions = []
        self.wrong_questions = []

    def add_question(self, question):
        self.questions.append(question)

    def ask_questions(self):
        shuffled_questions = random.sample(self.questions, len(self.questions))  # Shuffle the questions
        for question in shuffled_questions:
            question.ask()
            input("Press Enter to continue to the next question...")

    def retry(self):
        if not self.wrong_questions:
            print("You got all questions correct. There are no questions to retry.")
            return

        random.shuffle(self.wrong_questions)  # Shuffle the incorrect questions
        for question in self.wrong_questions:
            question.ask()
            input("Press Enter to continue to the next question...")

if __name__ == "__main__":
    reviewer = MultipleChoiceReviewer()

    # Add some questions to the reviewer
    reviewer.add_question(Question("p is an influence process that enable managers to get their people to do willingly what must be done, do well what ought to be done?",
     ["A. Influence", "B. Supervison", "C. Management", "D. Leadership"], "D"))
    reviewer.add_question(Question("defined as the process of influencing the activities of an organized group toward goal achievement?",
     ["A. Influence", "B. Supervison", "C. Management", "D. Leadership"], "D"))
    reviewer.add_question(Question("strategies for organizational effectiveness?",
     ["A. Management", "B. Assesment", "C. Leadership", "D. Plan"], "C"))
    reviewer.add_question(Question(" discovering the company's destiny and having the courage to follow it?",
                 ["A. Investment", "B. Leadership", "C. Vision", "D. Future"], "B"))
    reviewer.add_question(Question("interpersonal influence, exercised in a situation, and directed, through the communication process, toward the attainment of a specified goal or goals?",
                 ["A. Leadership", "B. Network", "C. Influence", "D. Mission"], "D"))
    reviewer.add_question(Question("involve structuring the roles of subordinates, providing them with instructions, and behaving in ways that will increase the performance of the group?",
                 ["A. Orientation", "B. People Oriented", "C. Task Oriented", "D. Work Oriented"], "C"))
    reviewer.add_question(Question(" include showing concern for employee feelings and treating employees with respect",
                 ["A. Orientation", "B. People Oriented", "C. Task Oriented", "D. Work Oriented"], "B"))
    reviewer.add_question(Question("leaders make the decision alone without necessarily involving employees in the decision-making process?",
                 ["A. Authoritarian", "B. Democratic", "C. Laissez-faire", "D. Monarchy"], "A"))
    reviewer.add_question(Question("employees participate in the making of the decision?",
                 ["A. Authoritarian", "B. Democratic", "C. Laissez-faire", "D. Monarchy"], "B"))
    reviewer.add_question(Question("leave employees alone to make the decision?",
                 ["A. Authoritarian", "B. Democratic", "C. Laissez-faire", "D. Monarchy"], "C"))
    reviewer.add_question(Question("Places too much value on social acceptance while neglecting technical tasks",
                 ["A. bocchi", "B. ally of justice", "C. good guy", "D. nice guy"], "D"))
    reviewer.add_question(Question("Neither obtains acceptance from others nor gets the job done",
                 ["A. nobody", "B. trash", "C. flop", "D. loser"], "D"))
    reviewer.add_question(Question("Balances both the needs of people and task factors",
                 ["A. compromiser", "B. adjudicator", "C. average guy", "D. balance guy"], "A"))
    reviewer.add_question(Question(": Is interested in getting the job done right without concern for human feelings",
                 ["A. robot", "B. task master", "C. AI", "D. master of task"], "B"))
    reviewer.add_question(Question("Gets the job done and at the same time makes everyone happy",
                 ["A. paragon", "B. perfect manager", "C. ideal manager", "D. flawless manager"], "C"))
    reviewer.add_question(Question("When the leader has low-quality relations with employees and has low position power, and the task at hand it relatively unstructured, the situation is very unfavorable",
                 ["A. Fiedler’s Contingency Theory", "B. Fiedler’s Theory", "C. Leadership Theory", "D. Fiedler’s Contingency Plan"], "A"))
    reviewer.add_question(Question("must use different leadership styles depending on their followers’ development level employee readiness",
                 ["A. Leadership based on Situation", "B. Situational Leadership", "C. Leadership based on condition", "D. Conditional Leadership"], "B"))
    reviewer.add_question(Question("leaders will create satisfied and high-performing employees by making sure that employee effort leads to performance, and their performance is rewarded by desired rewards",
                 ["A. Motivation Theory of Leadership", "B. Reward based leadership", "C. Path-Goal Theory of Leadership", "D. Theory of Goal oriented Leadership"], "C"))
    reviewer.add_question(Question("skills a leader must possess to enable him to understand and make decisions about work processes, activities, and technology",
                 ["A. Technical Skills", "B. Human Skills", "C. Conceptual Skills", "D. Passive Skills"], "A"))
    reviewer.add_question(Question("refer to the ability of a leader to deal with people, both inside and outside the organization",
                 ["A. Technical Skills", "B. Human Skills", "C. Conceptual Skills", "D. Passive Skills"], "B"))
    reviewer.add_question(Question("refer to the “ability to think in abstract terms, to see how parts fit together to form the whole.”",
                 ["A. Technical Skills", "B. Human Skills", "C. Conceptual Skills", "D. Passive Skills"], "C"))
    reviewer.add_question(Question("Arriving at conclusions and judgments with respect to priority, personnel, resources, policies, organizational structures, and strategic directions.”",
                 ["A. DECIDING", "B. COMMUNICATING", "C. MOTIVATING", "D. APPRECIATING"], "A"))
    reviewer.add_question(Question("Creating understanding and resolving conflicts by talking, meeting, or writing to others.",
                 ["A. DECIDING", "B. COMMUNICATING", "C. MOTIVATING", "D. APPRECIATING"], "B"))
    reviewer.add_question(Question("Inspiring, encouraging, or impelling others to take required action and creating workplace conditions to ensure work satisfaction.",
                 ["A. DECIDING", "B. COMMUNICATING", "C. MOTIVATING", "D. APPRECIATING"], "C"))
    reviewer.add_question(Question("Choosing the right employees for positions in the organization or for specific team activities",
                 ["A. SELECTION", "B. SELECTING PEOPLE", "C. NOMINATION", "D. FILTERING"], "B"))
    reviewer.add_question(Question("Helping employees improve their knowledge, attitudes, and skills.",
                 ["A. GROWTH", "B. DEVELOPING PEOPLE", "C. EVOLUTION", "D. ASCENSION"], "B"))
    reviewer.add_question(Question("Invite employees to take part in setting objectives and making decisions.",
                 ["A. Participation", "B. Invitation", "C. Night out", "D. Team building"], "A"))
    reviewer.add_question(Question("Set clear standards, relate the importance of the work, keep expectations reasonable, and respond to suggestions offered by employees",
                 ["A. Guidelines", "B. Communication", "C. Rule book", "D. Contract"], "B"))


class MultipleChoiceReviewer:
    def __init__(self):
        self.questions = []
        self.wrong_questions = []
        self.score = 0

    def add_question(self, question):
        self.questions.append(question)

    def ask_questions(self):
        shuffled_questions = random.sample(self.questions, len(self.questions))  # Shuffle the questions
        for question in shuffled_questions:
            if question.ask():
                self.score += 1
            else:
                self.wrong_questions.append(question)

            input("Press Enter to continue to the next question...")

    def retry(self):
        if not self.wrong_questions:
            print("You got all questions correct. There are no questions to retry.")
            return

        random.shuffle(self.wrong_questions)  # Shuffle the incorrect questions
        for question in self.wrong_questions:
            if question.ask():
                self.score += 1

            input("Press Enter to continue to the next question...")

    def display_score(self):
        print(f"Your score: {self.score}/{len(self.questions)}")

    while True:
        # Ask the user the questions
        reviewer.ask_questions()

        # Give the user the option to retry
        if reviewer.wrong_questions:
            print("You got some questions wrong. Let's retry them.")
            reviewer.retry()
        else:
            print("Congratulations! You got all the questions correct.")

        retry_choice = input("Do you want to retry the entire quiz? (yes/no): ").lower()
        if retry_choice != "yes":
            break
